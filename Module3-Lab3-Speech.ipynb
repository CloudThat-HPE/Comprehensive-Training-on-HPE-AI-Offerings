# %% [markdown]
# # Speech Recognition
#
# For speech recognition we are using the module named speech_recognition.  It is library for performing speech recognition, with support for several engines and APIs, online and offline.

# %%
import speech_recognition as sr
r = sr.Recognizer()

# %%
sr.__version__
# Out:
# '3.8.0'

# %%
filename = "test.wav"

# %%
# open the file
with sr.AudioFile(filename) as source:
    # listen for the data (load audio to memory)
    audio_data = r.record(source)
    # recognize (convert from speech to text)
    text = r.recognize_google(audio_data)
    print(text)
# Out:
# I love my country and I am proud of its rich and very Heritage I shall always strive to be worthy of it I shall give respect to my parents teachers and elders and treat everyone with courtesy to my country and my people I pledge my devotion in their well-being and prosperity alone last my happiness

# %% [markdown]
# # Word Cloud from recognized text
#
# we are using the library wordcloud for plotting the wordcloud from the recognized text

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
#Count the words collected from audio on Cloud
class WordCloudGeneration:

    def create_word_cloud(self, final_data):
        # initiate WordCloud object with parameters width, height, maximum font size and background color
        # call the generate method of WordCloud class to generate an image
        wordcloud = WordCloud(width=1600, height=800, max_words=10, max_font_size=200, background_color="black").generate(final_data)
        # plt the image generated by WordCloud class
        plt.figure(figsize=(12,10))
        plt.imshow(wordcloud)
        plt.axis("off")
        plt.show()

wordcloud_generator = WordCloudGeneration()
wordcloud_generator.create_word_cloud(text)

# %%
from gtts import gTTS

# %%
import os

# %%
mytext = 'Welcome to text-to-speech conversion!, i am amit, hellow learners keep learning keep growing'

# %%
language = 'en'

# %%
myobj = gTTS(text=mytext, lang=language, slow=False)

# %%
myobj.save("ttsp.mp3")
